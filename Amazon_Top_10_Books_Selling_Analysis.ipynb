# %% [markdown]
# 1. Title: The title of the book, represents its core identity.
# 2. Description: A concise yet informative overview of the book's content and themes.
# 3. Author: The name(s) of the author(s) responsible for creating the literary work.
# 4. ISBN-10: The International Standard Book Number in the 10-digit format, aiding in precise identification.
# 5. ISBN-13: The International Standard Book Number in the 13-digit format, enhancing global recognition.
# 6. Publish Date: The date on which the book was officially published, marking its entry into the literary world
# 7. Edition: Information about the edition of the book, if applicable, providing insights into its various releases
# 8. Best Seller: A binary indicator (1 or 0) signifying whether the book has achieved best-seller status.
# 9. Top Rated: A binary indicator (1 or 0) highlighting whether the book has received high ratings and acclaim from readers.
# 10. Rating: The average rating awarded to the book by Amazon customers, offering an assessment of its quality.
# 11. Review Count: The total number of user reviews posted for the book, reflecting reader engagement and feedback.
# 12. Price: The current price of the book on the Amazon platform, influences purchase decisions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/archive (7).zip")

# %%
data.head()
# Out:
#                               title  \
# 0         The Staff Engineer's Path
# 1     Cracking the Coding Interview
# 2  Python Crash Course, 3rd Edition
# 3          The Pragmatic Programmer
# 4                        Clean Code
#
#                                          description                   author  \
# 0  A Guide for Individual Contributors Navigating...             Tanya Reilly
# 1            189 Programming Questions and Solutions  Gayle Laakmann McDowell
# 2  A Hands-On, Project-Based Introduction to Prog...             Eric Matthes
# 3  20th Anniversary Edition, 2nd Edition: Your Jo...             David Thomas
# 4         A Handbook of Agile Software Craftsmanship         Robert C. Martin
#
#        isbn10          isbn13 publish_date edition best_seller top_rated   \
# 0  1098118731  978-1098118730   2022-10-25       1         Yes         No
# 1   984782869  978-0984782857   2015-07-01       6         Yes         No
# 2  1718502702  978-1718502703   2023-01-10       3         Yes         No
# 3         NaN  978-0135957059   2019-09-13       2         Yes         No
# 4         NaN  978-0132350884   2008-08-01       1         Yes         No
#
#   rating  ... Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0    4.7  ...         NaN         NaN          NaN          NaN          NaN
# 1    4.7  ...         NaN         NaN          NaN          NaN          NaN
# 2    4.8  ...         NaN         NaN          NaN          NaN          NaN
# 3    4.8  ...         NaN         NaN          NaN          NaN          NaN
# 4    4.7  ...         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
data.shape
# Out:
# (541, 26)

# %%
data.isnull().sum()
# Out:
# title            75
# description     154
# author           76
# isbn10          175
# isbn13           76
# publish_date     78
# edition          77
# best_seller      74
# top_rated        74
# rating           78
# review_count     78
# price            77
# Unnamed: 12     541
# Unnamed: 13     541
# Unnamed: 14     541
# Unnamed: 15     541
# Unnamed: 16     541
# Unnamed: 17     541
# Unnamed: 18     541
# Unnamed: 19     541
# Unnamed: 20     541
# Unnamed: 21     541
# Unnamed: 22     541
# Unnamed: 23     541
# Unnamed: 24     541
# Unnamed: 25     541
# dtype: int64

# %%
import missingno as misno
misno.bar(data)
plt.show()

# %%
data.isnull().all()
# Out:
# title           False
# description     False
# author          False
# isbn10          False
# isbn13          False
# publish_date    False
# edition         False
# best_seller     False
# top_rated       False
# rating          False
# review_count    False
# price           False
# Unnamed: 12      True
# Unnamed: 13      True
# Unnamed: 14      True
# Unnamed: 15      True
# Unnamed: 16      True
# Unnamed: 17      True
# Unnamed: 18      True
# Unnamed: 19      True
# Unnamed: 20      True
# Unnamed: 21      True
# Unnamed: 22      True
# Unnamed: 23      True
# Unnamed: 24      True
# Unnamed: 25      True
# dtype: bool

# %%
null_columns = data.columns[data.isnull().all()]

# %%
data = data.drop(columns = null_columns)

# %%
data.head()
# Out:
#                               title  \
# 0         The Staff Engineer's Path
# 1     Cracking the Coding Interview
# 2  Python Crash Course, 3rd Edition
# 3          The Pragmatic Programmer
# 4                        Clean Code
#
#                                          description                   author  \
# 0  A Guide for Individual Contributors Navigating...             Tanya Reilly
# 1            189 Programming Questions and Solutions  Gayle Laakmann McDowell
# 2  A Hands-On, Project-Based Introduction to Prog...             Eric Matthes
# 3  20th Anniversary Edition, 2nd Edition: Your Jo...             David Thomas
# 4         A Handbook of Agile Software Craftsmanship         Robert C. Martin
#
#        isbn10          isbn13 publish_date edition best_seller top_rated   \
# 0  1098118731  978-1098118730   2022-10-25       1         Yes         No
# 1   984782869  978-0984782857   2015-07-01       6         Yes         No
# 2  1718502702  978-1718502703   2023-01-10       3         Yes         No
# 3         NaN  978-0135957059   2019-09-13       2         Yes         No
# 4         NaN  978-0132350884   2008-08-01       1         Yes         No
#
#   rating review_count   price
# 0    4.7          189  $31.99
# 1    4.7         8334  $33.21
# 2    4.8          165  $30.61
# 3    4.8         2521  $38.00
# 4    4.7         5639  $40.00

# %%
misno.bar(data)
plt.show()

# %%
data.shape
# Out:
# (541, 12)

# %%
data = data.dropna()

# %%
data.shape
# Out:
# (293, 12)

# %%
misno.bar(data)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 293 entries, 0 to 466
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         293 non-null    object
#  1   description   293 non-null    object
#  2   author        293 non-null    object
#  3   isbn10        293 non-null    object
#  4   isbn13        293 non-null    object
#  5   publish_date  293 non-null    object
#  6   edition       293 non-null    object
#  7   best_seller   293 non-null    object
#  8   top_rated     293 non-null    object
#  9   rating        293 non-null    object
#  10  review_count  293 non-null    object
#  11  price         293 non-null    object
# dtypes: object(12)
# memory usage: 29.8+ KB

# %%
data.head()
# Out:
#                                                title  \
# 0                          The Staff Engineer's Path
# 1                      Cracking the Coding Interview
# 2                   Python Crash Course, 3rd Edition
# 6  Automate the Boring Stuff with Python, 2nd Edi...
# 7                                 The Manager's Path
#
#                                          description                   author  \
# 0  A Guide for Individual Contributors Navigating...             Tanya Reilly
# 1            189 Programming Questions and Solutions  Gayle Laakmann McDowell
# 2  A Hands-On, Project-Based Introduction to Prog...             Eric Matthes
# 6          Practical Programming for Total Beginners              Al Sweigart
# 7  A Guide for Tech Leaders Navigating Growth and...         Camille Fournier
#
#        isbn10          isbn13 publish_date edition best_seller top_rated   \
# 0  1098118731  978-1098118730   2022-10-25       1         Yes         No
# 1   984782869  978-0984782857   2015-07-01       6         Yes         No
# 2  1718502702  978-1718502703   2023-01-10       3         Yes         No
# 6  1593279922  978-1593279929   2019-11-12       2         Yes         No
# 7  1491973897  978-1491973899   2017-05-02       1         Yes         No
#
#   rating review_count   price
# 0    4.7          189  $31.99
# 1    4.7         8334  $33.21
# 2    4.8          165  $30.61
# 6    4.7         2858  $29.99
# 7    4.6         2504  $30.49

# %%
data["rating"].unique()
# Out:
# array(['4.7', '4.8', '4.6', '4.5', '4', '5', '4.3', '4.9', '4.2', '4.4',
#        '4.1', '3.9', '3.4', '$4.70 ', '0', '3.6', '3.7', '3.8'],
#       dtype=object)

# %%
# Clean and convert the "rating" column to float
data["rating"] = data["rating"].str.replace("[^\d.]", " ", regex = True).astype(float)

# %%
data["rating"].unique()
# Out:
# array([4.7, 4.8, 4.6, 4.5, 4. , 5. , 4.3, 4.9, 4.2, 4.4, 4.1, 3.9, 3.4,
#        0. , 3.6, 3.7, 3.8])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 293 entries, 0 to 466
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         293 non-null    object
#  1   description   293 non-null    object
#  2   author        293 non-null    object
#  3   isbn10        293 non-null    object
#  4   isbn13        293 non-null    object
#  5   publish_date  293 non-null    object
#  6   edition       293 non-null    object
#  7   best_seller   293 non-null    object
#  8   top_rated     293 non-null    object
#  9   rating        293 non-null    float64
#  10  review_count  293 non-null    object
#  11  price         293 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 29.8+ KB

# %%
sorted_data = data.sort_values(by = "rating", ascending  = False)
sorted_data
# Out:
#                                                  title  \
# 225                                      Learning eBPF
# 310             Mastering Linux Security and Hardening
# 413                                  Cloud Governance:
# 325  Microsoft Cybersecurity Architect Exam Ref SC-100
# 66                             Becoming KCNA Certified
# ..                                                 ...
# 459  Android Studio Flamingo Essentials - Java Edition
# 406                        The Day Google Disappeared:
# 407                            Search Engine Artistry:
# 253                                  React Programming
# 222                                  Black Hat GraphQL
#
#                                            description  \
# 225  Programming the Linux Kernel for Enhanced Obse...
# 310  A practical guide to protecting your Linux sys...
# 413  Basics and Practice (Professors of Practice) (...
# 325  Get certified with ease while learning how to ...
# 66   Build a strong foundation in cloud native and ...
# ..                                                 ...
# 459  Developing Android Apps Using Android Studio 2...
# 406  Understanding the State of the World without G...
# 407     A User's Guide to Optimizing Your Web Searches
# 253   The Big Nerd Ranch Guide (Big Nerd Ranch Guides)
# 222                     Attacking Next Generation APIs
#
#                          author      isbn10          isbn13 publish_date  \
# 225                    Liz Rice  1098135121  978-1098135126   2023-04-11
# 310           Donald A. Tevault  1837630518  978-1837630516   2023-02-28
# 413               Steven Mezzio  3110755262  978-3110755268   2022-12-05
# 325              Dwayne Natwick  1803242396  978-1803242392   2023-01-06
# 66                Dmitry Galkin  1804613398  978-1804613399   2023-02-10
# ..                          ...         ...             ...          ...
# 459                  Neil Smyth  1951442717  978-1951442712    16-May-23
# 406  Reynold J. Branche BSc MBA  9769708585  978-9769708587   2023-05-07
# 407  Reynold J. Branche BSc MBA  9769708542  978-9769708549   2023-04-25
# 253              Loren Klingman   137901763  978-0137901760   2023-04-29
# 222                  Nick Aleks  1718502842  978-1718502840   2023-05-23
#
#     edition best_seller top_rated   rating review_count    price
# 225       1          No         No     5.0            4   $52.99
# 310       3          No         No     5.0           16   $44.99
# 413       1          no         No     5.0            4   $29.99
# 325       1          No         No     5.0            5   $41.99
# 66        1          No         No     5.0            2   $36.22
# ..      ...         ...        ...     ...          ...      ...
# 459       1          No         No     0.0            0  $49.99
# 406       1          no         No     0.0            0   $15.95
# 407       1          no         No     0.0            0   $15.95
# 253       1          No         No     0.0            0   $49.99
# 222       1          No         No     0.0            0   $55.49
#
# [293 rows x 12 columns]

# %%
top_10_rating_author_name = sorted_data.head(10)
top_10_rating_author_name
# Out:
#                                                  title  \
# 225                                      Learning eBPF
# 310             Mastering Linux Security and Hardening
# 413                                  Cloud Governance:
# 325  Microsoft Cybersecurity Architect Exam Ref SC-100
# 66                             Becoming KCNA Certified
# 321  Configuring Windows Server Hybrid Advanced Ser...
# 312           Active Directory Administration Cookbook
# 35                                Rust Web Programming
# 311                An Ethical Guide to Cyber Anonymity
# 451  Certified Ethical Hacker (CEH) v12 312-50 Exam...
#
#                                            description  \
# 225  Programming the Linux Kernel for Enhanced Obse...
# 310  A practical guide to protecting your Linux sys...
# 413  Basics and Practice (Professors of Practice) (...
# 325  Get certified with ease while learning how to ...
# 66   Build a strong foundation in cloud native and ...
# 321  Configure advanced Windows Server services for...
# 312  Proven solutions to everyday identity and auth...
# 35   A hands-on guide to developing, packaging, and...
# 311  Concepts, tools, and techniques to protect you...
# 451  Keep up to date with ethical hacking trends an...
#
#                      author      isbn10          isbn13 publish_date edition  \
# 225                Liz Rice  1098135121  978-1098135126   2023-04-11       1
# 310       Donald A. Tevault  1837630518  978-1837630516   2023-02-28       3
# 413           Steven Mezzio  3110755262  978-3110755268   2022-12-05       1
# 325          Dwayne Natwick  1803242396  978-1803242392   2023-01-06       1
# 66            Dmitry Galkin  1804613398  978-1804613399   2023-02-10       1
# 321             Chris Gill   1804615099  978-1804615096   2023-04-28       1
# 312        Sander Berkouwer  1803242507  978-1803242507   2022-07-15       2
# 35          Maxwell Flitton  1803234695  978-1803234694   2023-01-27       2
# 311   Kushantha Gunawardana  1801810214  978-1801810210   2022-12-16       1
# 451           Dale Meredith  1801813094  978-1801813099     8-Jul-22       1
#
#     best_seller top_rated   rating review_count    price
# 225          No         No     5.0            4   $52.99
# 310          No         No     5.0           16   $44.99
# 413          no         No     5.0            4   $29.99
# 325          No         No     5.0            5   $41.99
# 66           No         No     5.0            2   $36.22
# 321          No         No     5.0            2   $44.99
# 312          No         No     5.0            6   $49.99
# 35          Yes         No     5.0            4   $44.99
# 311          No         No     5.0            4   $34.99
# 451          No         No     5.0            5  $44.99

# %%
plt.figure(figsize=(10,6))
num_rate = sns.barplot(x = "author", y = "rating", data = top_10_rating_author_name, palette = "Blues" )
for i in num_rate.containers:
  num_rate.bar_label(i)
plt.xticks(rotation = 34)
plt.title("Top 10 Authors Name With Highest Rating")
plt.xlabel("Autors Name", fontsize = 20)
plt.ylabel("Rating", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (10,6))
num_rate = sns.barplot(x = "author", y = "rating", data = top_10_rating_author_name, color='#D988B9', hue = "review_count" )
for i in num_rate.containers:
  num_rate.bar_label(i)

plt.xticks(rotation = 34)
plt.title("TOP 10 AUTHORS NAME WITH HIGHEST RATING")
plt.xlabel("Author", fontsize = 20)
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# **Book Description**

# %%
data.describe()
# Out:
#            rating
# count  293.000000
# mean     4.489078
# std      0.643314
# min      0.000000
# 25%      4.400000
# 50%      4.600000
# 75%      4.700000
# max      5.000000

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from wordcloud import ImageColorGenerator

text = " ".join(i for i in data.description)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure(figsize = (15,10))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
data["price"] = data["price"].str.replace("[^\d.]", " ", regex = True).astype(float)

# %%
data["price"].max()
# Out:
# 79.99

# %%
sorted_price = data.sort_values(by = "price", ascending = False)

# %%
Top_10_highest_price = sorted_price.head(10)

# %%
plt.figure(figsize = (10,6))
ax = sns.barplot(x = "title", y = "price", data  = Top_10_highest_price, palette='dark:#5A9_r')
for i in ax.containers:
  ax.bar_label(i)

plt.xticks(rotation = 90)
plt.xlabel("Books")
plt.title("Top 10 Books Price", fontsize = 20)
plt.ylabel("Price", fontsize = 20)
plt.show()
